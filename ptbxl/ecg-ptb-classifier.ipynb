# %% [markdown]
# Barış Özcan Kaggle https://www.kaggle.com/code/barzcan/ecg-ptb-classifier

# %%
# !pip install numpy
# !pip install pandas numpy
# !pip install wfdb
# !pip install ast
# Out:
# Requirement already satisfied: numpy in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (2.3.2)
# Requirement already satisfied: pandas in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (2.3.2)
# Requirement already satisfied: numpy in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting wfdb
#   Downloading wfdb-4.3.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting aiohttp>=3.10.11 (from wfdb)
#   Downloading aiohttp-3.12.15-cp313-cp313-win_amd64.whl.metadata (7.9 kB)
# Collecting fsspec>=2023.10.0 (from wfdb)
#   Downloading fsspec-2025.7.0-py3-none-any.whl.metadata (12 kB)
# Collecting matplotlib>=3.2.2 (from wfdb)
#   Downloading matplotlib-3.10.5-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.26.4 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from wfdb) (2.3.2)
# Requirement already satisfied: pandas>=2.2.3 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from wfdb) (2.3.2)
# Requirement already satisfied: requests>=2.8.1 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from wfdb) (2.32.5)
# Collecting scipy>=1.13.0 (from wfdb)
#   Downloading scipy-1.16.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting soundfile>=0.10.0 (from wfdb)
#   Downloading soundfile-0.13.1-py2.py3-none-win_amd64.whl.metadata (16 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp>=3.10.11->wfdb)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp>=3.10.11->wfdb)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from aiohttp>=3.10.11->wfdb) (25.3.0)
# Collecting frozenlist>=1.1.1 (from aiohttp>=3.10.11->wfdb)
#   Downloading frozenlist-1.7.0-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp>=3.10.11->wfdb)
#   Downloading multidict-6.6.4-cp313-cp313-win_amd64.whl.metadata (5.4 kB)
# Collecting propcache>=0.2.0 (from aiohttp>=3.10.11->wfdb)
#   Downloading propcache-0.3.2-cp313-cp313-win_amd64.whl.metadata (12 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp>=3.10.11->wfdb)
#   Downloading yarl-1.20.1-cp313-cp313-win_amd64.whl.metadata (76 kB)
# Requirement already satisfied: idna>=2.0 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp>=3.10.11->wfdb) (3.10)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.2.2->wfdb)
#   Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.2.2->wfdb)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.2.2->wfdb)
#   Downloading fonttools-4.59.1-cp313-cp313-win_amd64.whl.metadata (111 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.2.2->wfdb)
#   Downloading kiwisolver-1.4.9-cp313-cp313-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from matplotlib>=3.2.2->wfdb) (25.0)
# Collecting pillow>=8 (from matplotlib>=3.2.2->wfdb)
#   Downloading pillow-11.3.0-cp313-cp313-win_amd64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib>=3.2.2->wfdb)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from matplotlib>=3.2.2->wfdb) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from pandas>=2.2.3->wfdb) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from pandas>=2.2.3->wfdb) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->wfdb) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from requests>=2.8.1->wfdb) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from requests>=2.8.1->wfdb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from requests>=2.8.1->wfdb) (2025.8.3)
# Requirement already satisfied: cffi>=1.0 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from soundfile>=0.10.0->wfdb) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from cffi>=1.0->soundfile>=0.10.0->wfdb) (2.22)
# Downloading wfdb-4.3.0-py3-none-any.whl (163 kB)
# Downloading aiohttp-3.12.15-cp313-cp313-win_amd64.whl (449 kB)
# Downloading multidict-6.6.4-cp313-cp313-win_amd64.whl (45 kB)
# Downloading yarl-1.20.1-cp313-cp313-win_amd64.whl (86 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading frozenlist-1.7.0-cp313-cp313-win_amd64.whl (43 kB)
# Downloading fsspec-2025.7.0-py3-none-any.whl (199 kB)
# Downloading matplotlib-3.10.5-cp313-cp313-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.1 MB 1.3 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.0/8.1 MB 1.4 MB/s eta 0:00:06
#    ------ --------------------------------- 1.3/8.1 MB 1.3 MB/s eta 0:00:06
#    ------- -------------------------------- 1.6/8.1 MB 1.3 MB/s eta 0:00:05
#    --------- ------------------------------ 1.8/8.1 MB 1.4 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.1/8.1 MB 1.4 MB/s eta 0:00:05
#    ------------ --------------------------- 2.6/8.1 MB 1.5 MB/s eta 0:00:04
#    --------------- ------------------------ 3.1/8.1 MB 1.5 MB/s eta 0:00:04
#    ---------------- ----------------------- 3
whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ------------------------------ --------- 0.8/1.0 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 1.9 MB/s  0:00:00
# Installing collected packages: scipy, pyparsing, propcache, pillow, multidict, kiwisolver, fsspec, frozenlist, fonttools, cycler, contourpy, aiohappyeyeballs, yarl, soundfile, matplotlib, aiosignal, aiohttp, wfdb
#
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    ----------------------------------------  0/18 [scipy]
#    -- -------------------------------------  1/18 [pyparsing]
#    -- -------------------------------------  1/18 [pyparsing]
#    ------ ---------------------------------  3/18 [pillow]
#    ------ ---------------------------------  3/18 [pillow]
#    ------ ---------------------------------  3/18 [pillow]
#    ------ ---------------------------------  3/18 [pillow]
#    ------ ---------------------------------  3/18 [pillow]
#    ------ ---------------------------------  3/18 [pillow]
#    ------ ---------------------------------  3/18 [pillow]
#    ------ ---------------------------------  3/18 [pillow]
#    ------ ---------------------------------  3/18 [pillow]
#    ------ ---------------------------------  3/18 [pillow]
#    ------ ---------------------------------  3/18 [pillow]
#    ------ ---------------------------------  3/18 [pillow]
#    ------ ---------------------------------  3/18 [pillow]
#    -------- -------------------------------  4/18 [multidict]
#    ------------- --------------------------  6/18 [fsspec]
#    ------------- --------------------------  6/18 [fsspec]
#    ------------- --------------------------  6/18 [fsspec]
#    ------------- --------------------------  6/18 [fsspec]
#    ------------- --------------------------  6/18 [fsspec]
#    ------------- --------------------------  6/18 [fsspec]
#    ------------- --------------------------  6/18 [fsspec]
#    ------------- --------------------------  6/18 [fsspec]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ----------------- ----------------------  8/18 [fonttools]
#    ---------------------- ----------------- 10/18 [contourpy]
#    ---------------------- ----------------- 10/18 [contourpy]
#    ------------------------ --------------- 11/18 [aiohappyeyeballs]
#    -------------------------- ------------- 12/18 [yarl]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ------------------------------- -------- 14/18 [matplotlib]
#    ----------------------------------- ---- 16/18 [aiohttp]
#    ----------------------------------- ---- 16/18 [aiohttp]
#    ----------------------------------- ---- 16/18 [aiohttp]
#    ----------------------------------- ---- 16/18 [aiohttp]
#    ----------------------------------- ---- 16/18 [aiohttp]
#    ----------------------------------- ---- 16/18 [aiohttp]
#    ----------------------------------- ---- 16/18 [aiohttp]
#    ----------------------------------- ---- 16/18 [aiohttp]
#    ----------------------------------- ---- 16/18 [aiohttp]
#    ------------------------------------- -- 17/18 [wfdb]
#    ------------------------------------- -- 17/18 [wfdb]
#    ------------------------------------- -- 17/18 [wfdb]
#    ------------------------------------- -- 17/18 [wfdb]
#    ---------------------------------------- 18/18 [wfdb]
#
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.12.15 aiosignal-1.4.0 contourpy-1.3.3 cycler-0.12.1 fonttools-4.59.1 frozenlist-1.7.0 fsspec-2025.7.0 kiwisolver-1.4.9 matplotlib-3.10.5 multidict-6.6.4 pillow-11.3.0 propcache-0.3.2 pyparsing-3.2.3 scipy-1.16.1 soundfile-0.13.1 wfdb-4.3.0 yarl-1.20.1
# Collecting ast
#   Downloading AST-0.0.2.tar.gz (19 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   Getting requirements to build wheel did not run successfully.
#   exit code: 1
#
#   [24 lines of output]
#   Traceback (most recent call last):
#     File "C:\Users\milal\IdeaProjects\Projektarbeit_KI_EKG\.venv\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 389, in <module>
#       main()
#       ~~~~^^
#     File "C:\Users\milal\IdeaProjects\Projektarbeit_KI_EKG\.venv\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 373, in main
#       json_out["return_val"] = hook(**hook_input["kwargs"])
#                                ~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\milal\IdeaProjects\Projektarbeit_KI_EKG\.venv\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 143, in get_requires_for_build_wheel
#       return hook(config_settings)
#     File "C:\Users\milal\AppData\Local\Temp\pip-build-env-jx9xatt1\overlay\Lib\site-packages\setuptools\build_meta.py", line 331, in get_requires_for_build_wheel
#       return self._get_build_requires(config_settings, requirements=[])
#              ~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\milal\AppData\Local\Temp\pip-build-env-jx9xatt1\overlay\Lib\site-packages\setuptools\build_meta.py", line 301, in _get_build_requires
#       self.run_setup()
#       ~~~~~~~~~~~~~~^^
#     File "C:\Users\milal\AppData\Local\Temp\pip-build-env-jx9xatt1\overlay\Lib\site-packages\setuptools\build_meta.py", line 512, in run_setup
#       super().run_setup(setup_script=setup_script)
#       ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\milal\AppData\Local\Temp\pip-build-env-jx9xatt1\overlay\Lib\site-packages\setuptools\build_meta.py", line 317, in run_setup
#       exec(code, locals())
#       ~~~~^^^^^^^^^^^^^^^^
#     File "<string>", line 6, in <module>
#     File "<frozen codecs>", line 921, in open
#   FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\milal\\AppData\\Local\\Temp\\pip-install-b79ngce_\\ast_475d82551d0d48d3beced079774bacce\\AST/README'
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# Getting requirements to build wheel did not run successfully.
# exit code: 1
#
# See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
# !pip install tensorflow
# !pip install scikit-learn
# Out:
# Requirement already satisfied: tensorflow in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from tensorflow) (6.32.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from tensorflow) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from tensorflow) (1.74.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from tensorflow) (3.11.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from tensorflow) (2.3.2)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.8.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.8.2)
# Requirement already satisfied: pillow in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from keras>=3.10.0->tensorflow) (14.1.0)
# Requirement already satisfied: namex in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from keras>=3.10.0->tensorflow) (0.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.1-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from scikit-learn) (2.3.2)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from scikit-learn) (1.16.1)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.7.1-cp313-cp313-win_amd64.whl (8.7 MB)
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.7 MB 5.3 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.0/8.7 MB 3.2 MB/s eta 0:00:03
#    ------ --------------------------------- 1.3/8.7 MB 2.7 MB/s eta 0:00:03
#    -------- ------------------------------- 1.8/8.7 MB 2.3 MB/s eta 0:00:04
#    --------- ------------------------------ 2.1/8.7 MB 2.1 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.4/8.7 MB 1.9 MB/s eta 0:00:04
#    ------------ --------------------------- 2.6/8.7 MB 1.9 MB/s eta 0:00:04
#    -------------- ------------------------- 3.1/8.7 MB 1.8 MB/s eta 0:00:04
#    --------------- ------------------------ 3.4/8.7 MB 1.8 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.7/8.7 MB 1.8 MB/s eta 0:00:03
#    ------------------- -------------------- 4.2/8.7 MB 1.8 MB/s eta 0:00:03
#    --------------------- ------------------ 4.7/8.7 MB 1.8 MB/s eta 0:00:03
#    ---------------------- ----------------- 5.0/8.7 MB 1.9 MB/s eta 0:00:03
#    ------------------------- -------------- 5.5/8.7 MB 1.9 MB/s eta 0:00:02
#    -------------------------- ------------- 5.8/8.7 MB 1.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 6.3/8.7 MB 1.8 MB/s eta 0:00:02
#    ------------------------------ --------- 6.6/8.7 MB 1.8 MB/s eta 0:00:02
#    ------------------------------- -------- 6.8/8.7 MB 1.8 MB/s eta 0:00:02
#    -------------------------------- ------- 7.1/8.7 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.6/8.7 MB 1.8 MB/s eta 0:00:01
#    ------------------------------------ --- 7.9/8.7 MB 1.8 MB/s eta 0:00:01
#    -------------------------------------- - 8.4/8.7 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 8.7/8.7 MB 1.8 MB/s  0:00:04
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
#
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    ---------------------------------------- 3/3 [scikit-learn]
#
# Successfully installed joblib-1.5.1 scikit-learn-1.7.1 threadpoolctl-3.6.0

# %%
# !python -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (23.2.1)
# Collecting pip
#   Obtaining dependency information for pip from https://files.pythonhosted.org/packages/b7/3f/945ef7ab14dc4f9d7f40288d2df998d1837ee0888ec3659c813487572faa/pip-25.2-py3-none-any.whl.metadata
#   Downloading pip-25.2-py3-none-any.whl.metadata (4.7 kB)
# Downloading pip-25.2-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.8 MB 596.3 kB/s eta 0:00:03
#    --- ------------------------------------ 0.1/1.8 MB 1.4 MB/s eta 0:00:02
#    -------- ------------------------------- 0.4/1.8 MB 2.5 MB/s eta 0:00:01
#    ------------- -------------------------- 0.6/1.8 MB 3.0 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.8/1.8 MB 3.3 MB/s eta 0:00:01
#    --------------------- ------------------ 1.0/1.8 MB 3.4 MB/s eta 0:00:01
#    -------------------------- ------------- 1.1/1.8 MB 3.5 MB/s eta 0:00:01
#    ------------------------------ --------- 1.4/1.8 MB 3.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.6/1.8 MB 3.7 MB/s eta 0:00:01
#    -------------------------------------- - 1.7/1.8 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 3.3 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.2.1
#     Uninstalling pip-23.2.1:
#       Successfully uninstalled pip-23.2.1
# Successfully installed pip-25.2

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# %%
#!ls
# !dir
# Out:
#  Volume in Laufwerk C: hat keine Bezeichnung.
#  Volumeseriennummer: 4E17-A56D
#
#  Verzeichnis von C:\Users\milal\IdeaProjects\Projektarbeit_KI_EKG
#
# 25.08.2025  17:26    <DIR>          .
# 24.08.2025  19:16    <DIR>          ..
# 25.08.2025  16:53    <DIR>          .idea
# 25.08.2025  17:18    <DIR>          .venv
# 25.08.2025  17:26         1.415.159 ecg-ptb-classifier.ipynb
# 24.08.2025  19:16               474 Projektarbeit_KI_EKG.iml
#                2 Datei(en),      1.415.633 Bytes
#                4 Verzeichnis(se), 175.367.110.656 Bytes frei

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\milal\IdeaProjects\Projektarbeit_KI_EKG

# %%
import pandas as pd
import numpy as np
import wfdb
import ast

'''Nimmt eine Tabelle df, die Dateinamen enthält.

Je nach Abtastrate (100 Hz oder höher) wählt sie die richtigen Dateien.

wfdb.rdsamp liest die Rohsignale (ECG-Kurven).

Es werden nur die Signaldaten genommen, Metadaten ignoriert.

Ergebnis: numpy-Array mit vielen Herzkurven.'''

def load_raw_data(df, sampling_rate, path):
    if sampling_rate == 100:
        data = [wfdb.rdsamp(path+f) for f in df.filename_lr]
    else:
        data = [wfdb.rdsamp(path+f) for f in df.filename_hr]
    data = np.array([signal for signal, meta in data])
    return data

'''Lädt die Label-Datei (ptbxl_database.csv).

Jeder Datensatz hat eine ecg_id (eindeutige Nummer).

Spalte scp_codes enthält Text wie "{'NORM': 100}".

Mit ast.literal_eval wird daraus ein echtes Dictionary: {'NORM': 100}'''

#path = './Projektarbeit_KI_EKG/'
path = '../'

# load and convert annotation data
Y = pd.read_csv('ptbxl_database.csv', index_col='ecg_id')
#Y = pd.read_csv(path+'ptbxl_database.csv', index_col='ecg_id')
Y.scp_codes = Y.scp_codes.apply(lambda x: ast.literal_eval(x))

'''Liest die Rohsignale aus den Dateien.

X enthält die Kurven (die eigentlichen Herzschläge).'''
# Load raw signal data
X = load_raw_data(Y, sampling_rate, path)


'''Lädt eine Datei mit Infos, welche Codes zu welchen Diagnosen gehören.

Filtert nur die Spalten, die diagnostisch relevant sind.'''
# Load scp_statements.csv for diagnostic aggregation
agg_df = pd.read_csv('scp_statements.csv', index_col=0)
agg_df = agg_df[agg_df.diagnostic == 1]

'''Nimmt die Codes von einem Patienten (z. B. {'NORM': 100, 'MI': 50})

Übersetzt sie in eine übergeordnete Diagnose-Kategorie (z. B. „Normal“ oder „Myokardinfarkt“).'''
def aggregate_diagnostic(y_dic):
    tmp = []
    for key in y_dic.keys():
        if key in agg_df.index:
            tmp.append(agg_df.loc[key].diagnostic_class)
    return list(set(tmp))

'''Fügt die neue Spalte diagnostic_superclass in die Tabelle ein.'''
# Apply diagnostic superclass
Y['diagnostic_superclass'] = Y.scp_codes.apply(aggregate_diagnostic)

'''Manche Patienten haben keine Diagnose oder mehrere Diagnosen gleichzeitig.

Hier behält man nur die, die genau eine eindeutige Diagnose haben.

mask ist eine Art Filter.'''
# Filter rows where 'diagnostic_superclass' has either no label or multiple labels
mask = Y['diagnostic_superclass'].apply(lambda x: len(x) == 1)
Y_filtered = Y[mask]

# Now, you should also filter the raw signal data 'X' to match the updated labels
X_filtered = X[mask]

'''Die Datenbank hat eine Spalte strat_fold, die vorgibt, welche Daten ins Training und welche ins Testset kommen.

Hier wird Fold 10 als Test genommen, alle anderen fürs Training'''
# Continue to split data into train and test
test_fold = 10

# Train
X_train = X_filtered[np.where(Y_filtered.strat_fold != test_fold)]
y_train = Y_filtered[(Y_filtered.strat_fold != test_fold)].diagnostic_superclass

# Test
X_test = X_filtered[np.where(Y_filtered.strat_fold == test_fold)]
y_test = Y_filtered[Y_filtered.strat_fold == test_fold].diagnostic_superclass

'''Bisher war diagnostic_superclass eine Liste (z. B. ['NORM']).

Jetzt wird sie zu einem einfachen String ('NORM').'''
# To simplify y_train and y_test further, convert the list entries to single string labels
y_train = y_train.apply(lambda x: x[0])
y_test = y_test.apply(lambda x: x[0])

# %%
y_train.value_counts()
# Out:
# diagnostic_superclass
# NORM    8157
# MI      2276
# STTC    2158
# CD      1524
# HYP      479
# Name: count, dtype: int64

# %%
y_test.value_counts()
# Out:
# diagnostic_superclass
# NORM    912
# MI      256
# STTC    242
# CD      184
# HYP      56
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

def plot_ecg_examples(X, Y, num_examples=5):
    # Randomly select some examples
    idx = np.random.choice(np.arange(len(X)), num_examples, replace=False)
    
    for i in idx:
        plt.figure(figsize=(10, 3))
        plt.plot(X[i].T)  # If your ECG data has multiple channels, they'll all be plotted.
        plt.title(f"Diagnostic Superclass: {', '.join(Y.iloc[i])}")
        plt.xlabel('Time')
        plt.ylabel('Amplitude')
        plt.grid(True)
        plt.show()

# To visualize 5 random examples from the training set:
plot_ecg_examples(X_train, y_train, num_examples=5)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def plot_single_ecg_example(X, Y):
    # Randomly select one example
    idx = np.random.choice(np.arange(len(X)))
    
    sample_ecg = X[idx]
    label = Y.iloc[idx]
    
    # Create a 12x1 grid of plots
    fig, axs = plt.subplots(nrows=12, ncols=1, figsize=(10, 15))
    
    for i in range(12):
        sns.lineplot(x=np.arange(sample_ecg.shape[1]), y=sample_ecg[i], ax=axs[i])
        axs[i].set_title(f"Channel {i+1}")
        axs[i].set_ylabel('Amplitude')
        axs[i].grid(True)
    
    plt.tight_layout()
    plt.suptitle(f"Diagnostic Superclass: {', '.join(label)}", y=1.02)
    plt.show()

# To visualize a random example from the training set:
plot_single_ecg_example(X_train, y_train)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
X_train = np.array(X_train)
X_test = np.array(X_test)

# If y_train and y_test are lists of labels, convert them to categorical format
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

# Initialize the LabelEncoder
le = LabelEncoder()

# Combine train and test labels
all_labels = pd.concat([y_train, y_test])

# Fit on combined labels
le.fit(all_labels)

# Transform separately
y_train_enc = le.transform(y_train)
y_test_enc = le.transform(y_test)

y_train_cat = to_categorical(y_train_enc)
y_test_cat = to_categorical(y_test_enc)

# %%
# Unique labels and their counts in the training set
train_label_counts = y_train.value_counts()

# Unique labels and their counts in the test set
test_label_counts = y_test.value_counts()

print("Training Labels:")
print(train_label_counts)

print("\nTest Labels:")
print(test_label_counts)
# Out:
# Training Labels:
# diagnostic_superclass
# NORM    8157
# MI      2276
# STTC    2158
# CD      1524
# HYP      479
# Name: count, dtype: int64
#
# Test Labels:
# diagnostic_superclass
# NORM    912
# MI      256
# STTC    242
# CD      184
# HYP      56
# Name: count, dtype: int64

# %%
input_shape = (X_train.shape[1], X_train.shape[2])  # (number_of_time_points, 12)
input_shape
# Out:
# (1000, 12)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv1D(filters=64, kernel_size=5, activation='relu', input_shape=input_shape))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(filters=128, kernel_size=5, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(y_train_cat.shape[1], activation='softmax'))

model.summary()
# Out:
# C:\Users\milal\IdeaProjects\Projektarbeit_KI_EKG\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 996, 64)        │         3,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 498, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 494, 128)       │        41,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 247, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 31616)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     4,046,976 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,092,613 (15.61 MB)
#  Trainable params: 4,092,613 (15.61 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(X_train, y_train_cat, epochs=10, batch_size=32, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/10
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 15s 37ms/step - accuracy: 0.6675 - loss: 0.9620 - val_accuracy: 0.7157 - val_loss: 0.8182
# Epoch 2/10
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - accuracy: 0.7507 - loss: 0.7333 - val_accuracy: 0.7239 - val_loss: 0.7705
# Epoch 3/10
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - accuracy: 0.7903 - loss: 0.5987 - val_accuracy: 0.7348 - val_loss: 0.7370
# Epoch 4/10
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 14s 38ms/step - accuracy: 0.8301 - loss: 0.4860 - val_accuracy: 0.7386 - val_loss: 0.8232
# Epoch 5/10
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 14s 38ms/step - accuracy: 0.8730 - loss: 0.3683 - val_accuracy: 0.7324 - val_loss: 0.8538
# Epoch 6/10
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 14s 38ms/step - accuracy: 0.9100 - loss: 0.2584 - val_accuracy: 0.7304 - val_loss: 1.0203
# Epoch 7/10
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 14s 38ms/step - accuracy: 0.9400 - loss: 0.1729 - val_accuracy: 0.7331 - val_loss: 1.1385
# Epoch 8/10
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.9537 - loss: 0.1437 - val_accuracy: 0.7307 - val_loss: 1.3012
# Epoch 9/10
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.9614 - loss: 0.1132 - val_accuracy: 0.7331 - val_loss: 1.3373
# Epoch 10/10
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.9699 - loss: 0.0880 - val_accuracy: 0.7314 - val_loss: 1.4515

# %%
#Evaluate on test data
test_loss, test_accuracy = model.evaluate(X_test, y_test_cat)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7242 - loss: 1.5762
# Test Loss: 1.5762344598770142
# Test Accuracy: 0.7242424488067627

# %%
#!pip install keras-tuner wandb
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.7-py3-none-any.whl.metadata (5.4 kB)
# Collecting wandb
#   Downloading wandb-0.21.1-py3-none-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: keras in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from keras-tuner) (3.11.3)
# Requirement already satisfied: packaging in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from keras-tuner) (25.0)
# Requirement already satisfied: requests in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from keras-tuner) (2.32.5)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl.metadata (221 bytes)
# Collecting click!=8.0.0,>=7.1 (from wandb)
#   Downloading click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting gitpython!=3.1.29,>=1.0.0 (from wandb)
#   Downloading gitpython-3.1.45-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: platformdirs in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from wandb) (4.3.8)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from wandb) (6.32.0)
# Collecting pydantic<3 (from wandb)
#   Downloading pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# Requirement already satisfied: pyyaml in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from wandb) (6.0.2)
# Collecting sentry-sdk>=2.0.0 (from wandb)
#   Downloading sentry_sdk-2.35.1-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: typing-extensions<5,>=4.8 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from wandb) (4.15.0)
# Collecting annotated-types>=0.6.0 (from pydantic<3->wandb)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic<3->wandb)
#   Downloading pydantic_core-2.33.2-cp313-cp313-win_amd64.whl.metadata (6.9 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<3->wandb)
#   Downloading typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from requests->keras-tuner) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from requests->keras-tuner) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from requests->keras-tuner) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from requests->keras-tuner) (2025.8.3)
# Requirement already satisfied: colorama in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from click!=8.0.0,>=7.1->wandb) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.29,>=1.0.0->wandb)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: absl-py in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from keras->keras-tuner) (2.3.1)
# Requirement already satisfied: numpy in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from keras->keras-tuner) (2.3.2)
# Requirement already satisfied: rich in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from keras->keras-tuner) (14.1.0)
# Requirement already satisfied: namex in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from keras->keras-tuner) (0.1.0)
# Requirement already satisfied: h5py in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from keras->keras-tuner) (3.14.0)
# Requirement already satisfied: optree in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from keras->keras-tuner) (0.17.0)
# Requirement already satisfied: ml-dtypes in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from keras->keras-tuner) (0.5.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from rich->keras->keras-tuner) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from rich->keras->keras-tuner) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\milal\ideaprojects\projektarbeit_ki_ekg\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner) (0.1.2)
# Downloading keras_tuner-1.4.7-py3-none-any.whl (129 kB)
# Downloading wandb-0.21.1-py3-none-win_amd64.whl (21.6 MB)
#    ---------------------------------------- 0.0/21.6 MB ? eta -:--:--
#    - -------------------------------------- 0.8/21.6 MB 4.4 MB/s eta 0:00:05
#    -- ------------------------------------- 1.3/21.6 MB 3.5 MB/s eta 0:00:06
#    -- ------------------------------------- 1.6/21.6 MB 3.0 MB/s eta 0:00:07
#    --- ------------------------------------ 1.8/21.6 MB 2.6 MB/s eta 0:00:08
#    --- ------------------------------------ 2.1/21.6 MB 1.9 MB/s eta 0:00:11
#    ---- ----------------------------------- 2.4/21.6 MB 1.9 MB/s eta 0:00:11
#    ----- ---------------------------------- 2.9/21.6 MB 1.9 MB/s eta 0:00:10
#    ------ --------------------------------- 3.4/21.6 MB 2.0 MB/s eta 0:00:10
#    ------- -------------------------------- 3.9/21.6 MB 2.1 MB/s eta 0:00:09
#    -------- ------------------------------- 4.5/21.6 MB 2.1 MB/s eta 0:00:09
#    --------- ------------------------------ 5.0/21.6 MB 2.1 MB/s eta 0:00:08
#    ---------- ----------------------------- 5.5/21.6 MB 2.1 MB/s eta 0:00:08
#    ---------- ----------------------------- 5.8/21.6 MB 2.2 MB/s eta 0:00:08
#    ----------- ---------------------------- 6.3/21.6 MB 2.1 MB/s eta 0:00:08
#    ------------ --------------------------- 6.8/21.6 MB 2.1 MB/s eta 0:00:07
#    ------------- -------------------------- 7.1/21.6 MB 2.1 MB/s eta 0:00:07
#    -------------- ------------------------- 7.6/21.6 MB 2.1 MB/s eta 0:00:07
#    -------------- ------------------------- 7.9/21.6 MB 2.1 MB/s eta 0:00:07
#    --------------- ------------------------ 8.4/21.6 MB 2.1 MB/s eta 0:00:07
#    ---------------- ----------------------- 8.9/21.6 MB 2.1 MB/s eta 0:00:07
#    ----------------- ---------------------- 9.4/21.6 MB 2.1 MB/s eta 0:00:06
#    ------------------ --------------------- 10.0/21.6 MB 2.1 MB/s eta 0:00:06
#    ------------------ --------------------- 10.2/21.6 MB 2.1 MB/s eta 0:00:06
#    ------------------- -------------------- 10.5/21.6 MB 2.1 MB/s eta 0:00:06
#    -------------------- ------------------- 11.0/21.6 MB 2.1 MB/s eta 0:00:06
#    --------------------- ------------------ 11.5/21.6 MB 2.1 MB/s eta 0:00:05
#    ---------------------- ----------------- 12.1/21.6 MB 2.1 MB/s eta 0:00:05
#    ----------------------- ---------------- 12.6/21.6 MB 2.1 MB/s eta 0:00:05
#    ------------------------ --------------- 13.1/21.6 MB 2.1 MB/s eta 0:00:04
#    ------------------------- -------------- 13.6/21.6 MB 2.2 MB/s eta 0:00:04
#    ------------------------- -------------- 13.9/21.6 MB 2.1 MB/s eta 0:00:04
#    -------------------------- ------------- 14.4/21.6 MB 2.1 MB/s eta 0:00:04
#    --------------------------- ------------ 14.9/21.6 MB 2.2 MB/s eta 0:00:04
#    ---------------------------- ----------- 15.5/21.6 MB 2.2 MB/s eta 0:00:03
#    ------------------------------ --------- 16.3/21.6 MB 2.2 MB/s eta 0:00:03
#    ------------------------------- -------- 17.0/21.6 MB 2.2 MB/s eta 0:00:03
#    -------------------------------- ------- 17.6/21.6 MB 2.3 MB/s eta 0:00:02
#    --------------------------------- ------ 18.1/21.6 MB 2.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 18.6/21.6 MB 2.3 MB/s eta 0:00:02
#    ----------------------------------- ---- 18.9/21.6 MB 2.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 19.4/21.6 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------ --- 19.7/21.6 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------ --- 19.9/21.6 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------ --- 19.9/21.6 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------- -- 20.4/21.6 MB 2.2 MB/s eta 0:00:01
#    -------------------------------------- - 20.7/21.6 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  21.2/21.6 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 21.6/21.6 MB 2.1 MB/s  0:00:09
# Downloading pydantic-2.11.7-py3-none-any.whl (444 kB)
# Downloading pydantic_core-2.33.2-cp313-cp313-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.0 MB 1.9 MB/s eta 0:00:01
#    --------------------- ------------------ 1.0/2.0 MB 1.6 MB/s eta 0:00:01
#    -------------------------- ------------- 1.3/2.0 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------- -- 1.8/2.0 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 1.7 MB/s  0:00:01
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading click-8.2.1-py3-none-any.whl (102 kB)
# Downloading gitpython-3.1.45-py3-none-any.whl (208 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Downloading sentry_sdk-2.35.1-py2.py3-none-any.whl (363 kB)
# Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Installing collected packages: kt-legacy, typing-inspection, smmap, sentry-sdk, pydantic-core, click, annotated-types, pydantic, gitdb, gitpython, wandb, keras-tuner
#
#    ----------------------------------------  0/12 [kt-legacy]
#    --- ------------------------------------  1/12 [typing-inspection]
#    ------ ---------------------------------  2/12 [smmap]
#    ---------- -----------------------------  3/12 [sentry-sdk]
#    ---------- -----------------------------  3/12 [sentry-sdk]
#    ---------- -----------------------------  3/12 [sentry-sdk]
#    ---------- -----------------------------  3/12 [sentry-sdk]
#    ---------- -----------------------------  3/12 [sentry-sdk]
#    ---------- -----------------------------  3/12 [sentry-sdk]
#    ---------- -----------------------------  3/12 [sentry-sdk]
#    ---------- -----------------------------  3/12 [sentry-sdk]
#    ---------- -----------------------------  3/12 [sentry-sdk]
#    ---------- -----------------------------  3/12 [sentry-sdk]
#    ---------- -----------------------------  3/12 [sentry-sdk]
#    ---------- -----------------------------  3/12 [sentry-sdk]
#    ---------- -----------------------------  3/12 [sentry-sdk]
#    ---------- -----------------------------  3/12 [sentry-sdk]
#    ---------- -----------------------------  3/12 [sentry-sdk]
#    ---------- -----------------------------  3/12 [sentry-sdk]
#    ---------- -----------------------------  3/12 [sentry-sdk]
#    ---------- -----------------------------  3/12 [sentry-sdk]
#    ---------- -----------------------------  3/12 [sentry-sdk]
#    ---------- -----------------------------  3/12 [sentry-sdk]
#    ---------- -----------------------------  3/12 [sentry-sdk]
#    ------------- --------------------------  4/12 [pydantic-core]
#    ---------------- -----------------------  5/12 [click]
#    ---------------- -----------------------  5/12 [click]
#    -------------------- -------------------  6/12 [annotated-types]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    -------------------------- -------------  8/12 [gitdb]
#    -------------------------- -------------  8/12 [gitdb]
#    -------------------------- -------------  8/12 [gitdb]
#    ------------------------------ ---------  9/12 [gitpython]
#    ------------------------------ ---------  9/12 [gitpython]
#    ------------------------------ ---------  9/12 [gitpython]
#    ------------------------------ ---------  9/12 [gitpython]
#    ------------------------------ ---------  9/12 [gitpython]
#    ------------------------------ ---------  9/12 [gitpython]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    --------------------------------- ------ 10/12 [wandb]
#    ------------------------------------ --- 11/12 [keras-tuner]
#    ------------------------------------ --- 11/12 [keras-tuner]
#    ------------------------------------ --- 11/12 [keras-tuner]
#    ------------------------------------ --- 11/12 [keras-tuner]
#    ------------------------------------ --- 11/12 [keras-tuner]
#    ------------------------------------ --- 11/12 [keras-tuner]
#    ------------------------------------ --- 11/12 [keras-tuner]
#    ------------------------------------ --- 11/12 [keras-tuner]
#    ------------------------------------ --- 11/12 [keras-tuner]
#    ---------------------------------------- 12/12 [keras-tuner]
#
# Successfully installed annotated-types-0.7.0 click-8.2.1 gitdb-4.0.12 gitpython-3.1.45 keras-tuner-1.4.7 kt-legacy-1.0.5 pydantic-2.11.7 pydantic-core-2.33.2 sentry-sdk-2.35.1 smmap-5.0.2 typing-inspection-0.4.1 wandb-0.21.1

# %%
#!pip install wandb

# %%
'''
import tensorflow as tf
import wandb
from wandb.integration.keras import WandbCallback

#from wandb.keras import WandbCallback
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from kerastuner.tuners import RandomSearch
import matplotlib.pyplot as plt
# 1. Set up Weights & Biases for logging
wandb.init(project="EKG-CONV1D")
'''
# Out:
# '\nimport tensorflow as tf\nimport wandb\nfrom wandb.integration.keras import WandbCallback\n\n#from wandb.keras import WandbCallback\nfrom tensorflow.keras.models import Sequential\nfrom tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout\nfrom kerastuner.tuners import RandomSearch\nimport matplotlib.pyplot as plt\n# 1. Set up Weights & Biases for logging\nwandb.init(project="EKG-CONV1D")\n'

# %%
'''
import tensorflow as tf
import wandb
from wandb.keras import WandbCallback
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout,Activation,LeakyReLU
from kerastuner.tuners import RandomSearch
import matplotlib.pyplot as plt


# 1. Set up Weights & Biases for logging
wandb.init(project="EKG-CONV1D")

def build_model(hp):
    model = Sequential()

    # Input Layer
    activation_1 = hp.Choice('activation_1', values=['relu', 'tanh', 'sigmoid', 'leaky_relu'])
    model.add(Conv1D(filters=hp.Int('filters_1', 16, 256, step=32), 
                     kernel_size=hp.Int('kernel_size_1', 2, 8, step=2),
                     input_shape=input_shape))
    if activation_1 == "leaky_relu":
        model.add(LeakyReLU())
    else:
        model.add(Activation(activation_1))
    model.add(MaxPooling1D(pool_size=2))

    # Additional Convolutional Layers
    for i in range(hp.Int('num_conv_layers', 1, 3)):
        activation_conv = hp.Choice(f'activation_conv_{i+2}', values=['relu', 'tanh', 'sigmoid', 'leaky_relu'])
        model.add(Conv1D(filters=hp.Int(f'filters_{i+2}', 16, 256, step=32), 
                         kernel_size=hp.Int(f'kernel_size_{i+2}', 2, 8, step=2)))
        if activation_conv == "leaky_relu":
            model.add(LeakyReLU())
        else:
            model.add(Activation(activation_conv))
        model.add(MaxPooling1D(pool_size=2))

    model.add(Flatten())

    # Dense Layers
    activation_dense_1 = hp.Choice('activation_dense_1', values=['relu', 'tanh', 'sigmoid', 'leaky_relu'])
    model.add(Dense(hp.Int('dense_units_1', 32, 512, step=32)))
    if activation_dense_1 == "leaky_relu":
        model.add(LeakyReLU())
    else:
        model.add(Activation(activation_dense_1))
    model.add(Dropout(hp.Float('dropout_1', 0.0, 0.5, step=0.1)))

    for i in range(hp.Int('num_dense_layers', 1, 2)):
        activation_dense = hp.Choice(f'activation_dense_{i+2}', values=['relu', 'tanh', 'sigmoid', 'leaky_relu'])
        model.add(Dense(hp.Int(f'dense_units_{i+2}', 32, 512, step=32)))
        if activation_dense == "leaky_relu":
            model.add(LeakyReLU())
        else:
            model.add(Activation(activation_dense))
        model.add(Dropout(hp.Float(f'dropout_{i+2}', 0.0, 0.5, step=0.1)))

    # Output Layer
    model.add(Dense(y_train_cat.shape[1], activation='softmax'))

    # Compiling
    model.compile(optimizer=hp.Choice('optimizer', ['adam', 'sgd', 'rmsprop']),
                  loss='categorical_crossentropy', 
                  metrics=['accuracy'])

    return model

# 3. Set up RandomSearch with KerasTuner
tuner = RandomSearch(
    build_model,
    objective='val_loss',
    max_trials=50,
    executions_per_trial=1,
    directory='random_search_logs',
    project_name='kerastuner_wandb_integration')

# 4. Start the Search using the tuner
tuner.search(X_train, y_train_cat, 
             epochs=20,  # or any other integer value you want
             batch_size=64,  # or any other integer value you want
             validation_split=0.2, 
             callbacks=[WandbCallback()])
'''
# Out:
# '\nimport tensorflow as tf\nimport wandb\nfrom wandb.keras import WandbCallback\nfrom tensorflow.keras.models import Sequential\nfrom tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout,Activation,LeakyReLU\nfrom kerastuner.tuners import RandomSearch\nimport matplotlib.pyplot as plt\n\n\n# 1. Set up Weights & Biases for logging\nwandb.init(project="EKG-CONV1D")\n\ndef build_model(hp):\n    model = Sequential()\n\n    # Input Layer\n    activation_1 = hp.Choice(\'activation_1\', values=[\'relu\', \'tanh\', \'sigmoid\', \'leaky_relu\'])\n    model.add(Conv1D(filters=hp.Int(\'filters_1\', 16, 256, step=32), \n                     kernel_size=hp.Int(\'kernel_size_1\', 2, 8, step=2),\n                     input_shape=input_shape))\n    if activation_1 == "leaky_relu":\n        model.add(LeakyReLU())\n    else:\n        model.add(Activation(activation_1))\n    model.add(MaxPooling1D(pool_size=2))\n\n    # Additional Convolutional Layers\n    for i in range(hp.Int(\'num_conv_layers\', 1, 3)):\n        activation_conv = hp.Choice(f\'activation_conv_{i+2}\', values=[\'relu\', \'tanh\', \'sigmoid\', \'leaky_relu\'])\n        model.add(Conv1D(filters=hp.Int(f\'filters_{i+2}\', 16, 256, step=32), \n                         kernel_size=hp.Int(f\'kernel_size_{i+2}\', 2, 8, step=2)))\n        if activation_conv == "leaky_relu":\n            model.add(LeakyReLU())\n        else:\n            model.add(Activation(activation_conv))\n        model.add(MaxPooling1D(pool_size=2))\n\n    model.add(Flatten())\n\n    # Dense Layers\n    activation_dense_1 = hp.Choice(\'activation_dense_1\', values=[\'relu\', \'tanh\', \'sigmoid\', \'leaky_relu\'])\n    model.add(Dense(hp.Int(\'dense_units_1\', 32, 512, step=32)))\n    if activation_dense_1 == "leaky_relu":\n        model.add(LeakyReLU())\n    else:\n        model.add(Activation(activation_dense_1))\n    model.add(Dropout(hp.Float(\'dropout_1\', 0.0, 0.5, step=0.1)))\n\n    for i in range(hp.Int(\'num_dense_layers\', 1, 2)):\n        activation_dense = hp.Choice(f\'activation_dense_{i+2}\', values=[\'relu\', \'tanh\', \'sigmoid\', \'leaky_relu\'])\n        model.add(Dense(hp.Int(f\'dense_units_{i+2}\', 32, 512, step=32)))\n        if activation_dense == "leaky_relu":\n            model.add(LeakyReLU())\n        else:\n            model.add(Activation(activation_dense))\n        model.add(Dropout(hp.Float(f\'dropout_{i+2}\', 0.0, 0.5, step=0.1)))\n\n    # Output Layer\n    model.add(Dense(y_train_cat.shape[1], activation=\'softmax\'))\n\n    # Compiling\n    model.compile(optimizer=hp.Choice(\'optimizer\', [\'adam\', \'sgd\', \'rmsprop\']),\n                  loss=\'categorical_crossentropy\', \n                  metrics=[\'accuracy\'])\n\n    return model\n\n# 3. Set up RandomSearch with KerasTuner\ntuner = RandomSearch(\n    build_model,\n    objective=\'val_loss\',\n    max_trials=50,\n    executions_per_trial=1,\n    directory=\'random_search_logs\',\n    project_name=\'kerastuner_wandb_integration\')\n\n# 4. Start the Search using the tuner\ntuner.search(X_train, y_train_cat, \n             epochs=20,  # or any other integer value you want\n             batch_size=64,  # or any other integer value you want\n             validation_split=0.2, \n             callbacks=[WandbCallback()])\n'

# %%
'''
# 5. Retrain best model to get the history
best_model = tuner.get_best_models(num_models=1)[0]
history = best_model.fit(X_train, y_train_cat, epochs=10, validation_split=0.2).history

plt.figure(figsize=(10, 6))
plt.plot(history['accuracy'], label='Accuracy')
plt.plot(history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Save plot to a file
plot_filename = "accuracy_plot.png"
plt.savefig(plot_filename)
plt.show()

# 6. Log test metrics and plot to wandb
test_loss, test_accuracy = best_model.evaluate(X_test, y_test_cat)
wandb.log({'test_loss': test_loss, 'test_accuracy': test_accuracy, 'Accuracy Plot': wandb.Image(plot_filename)})

# 7. Save the best model and display its parameters
best_model.save("best_model.h5")
print("Best Model Parameters:", tuner.oracle.get_best_trials(num_trials=1)[0].hyperparameters.values)
'''
# Out:
# '\n# 5. Retrain best model to get the history\nbest_model = tuner.get_best_models(num_models=1)[0]\nhistory = best_model.fit(X_train, y_train_cat, epochs=10, validation_split=0.2).history\n\nplt.figure(figsize=(10, 6))\nplt.plot(history[\'accuracy\'], label=\'Accuracy\')\nplt.plot(history[\'val_accuracy\'], label=\'Validation Accuracy\')\nplt.xlabel(\'Epoch\')\nplt.ylabel(\'Accuracy\')\nplt.legend()\n\n# Save plot to a file\nplot_filename = "accuracy_plot.png"\nplt.savefig(plot_filename)\nplt.show()\n\n# 6. Log test metrics and plot to wandb\ntest_loss, test_accuracy = best_model.evaluate(X_test, y_test_cat)\nwandb.log({\'test_loss\': test_loss, \'test_accuracy\': test_accuracy, \'Accuracy Plot\': wandb.Image(plot_filename)})\n\n# 7. Save the best model and display its parameters\nbest_model.save("best_model.h5")\nprint("Best Model Parameters:", tuner.oracle.get_best_trials(num_trials=1)[0].hyperparameters.values)\n'

# %%
import tensorflow as tf
import wandb
#from wandb.keras import WandbCallback
#from wandb.integration.keras import WandbCallback
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, Activation, LeakyReLU
from kerastuner.tuners import RandomSearch
from tensorflow.keras.callbacks import EarlyStopping  # Added import
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import Callback  # Corrected import


# 1. Set up Weights & Biases for logging
#wandb.init(project="EKG-CONV1D")

# Define the EarlyStopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# Define a list of different learning rates to search through
learning_rates = [1e-2, 1e-3, 1e-4]

'''
def build_model(hp):
    model = Sequential()

    # Input Layer
    activation_1 = hp.Choice('activation_1', values=['relu', 'tanh', 'sigmoid', 'leaky_relu'])
    model.add(Conv1D(filters=hp.Int('filters_1', 16, 256, step=32), 
                     kernel_size=hp.Int('kernel_size_1', 2, 8, step=1),
                     input_shape=input_shape))
    if activation_1 == "leaky_relu":
        model.add(LeakyReLU())
    else:
        model.add(Activation(activation_1))
    model.add(MaxPooling1D(pool_size=2))

    # Additional Convolutional Layers
    for i in range(hp.Int('num_conv_layers', 1, 3)):
        activation_conv = hp.Choice(f'activation_conv_{i+2}', values=['relu', 'tanh', 'sigmoid', 'leaky_relu'])
        model.add(Conv1D(filters=hp.Int(f'filters_{i+2}', 16, 256, step=32), 
                         kernel_size=hp.Int(f'kernel_size_{i+2}', 2, 8, step=2)))
        if activation_conv == "leaky_relu":
            model.add(LeakyReLU())
        else:
            model.add(Activation(activation_conv))
        model.add(MaxPooling1D(pool_size=2))

    model.add(Flatten())

    # Dense Layers
    activation_dense_1 = hp.Choice('activation_dense_1', values=['relu', 'tanh', 'sigmoid', 'leaky_relu'])
    model.add(Dense(hp.Int('dense_units_1', 32, 512, step=32)))
    if activation_dense_1 == "leaky_relu":
        model.add(LeakyReLU())
    else:
        model.add(Activation(activation_dense_1))
    model.add(Dropout(hp.Float('dropout_1', 0.0, 0.5, step=0.1)))

    for i in range(hp.Int('num_dense_layers', 1, 2)):
        activation_dense = hp.Choice(f'activation_dense_{i+2}', values=['relu', 'tanh', 'sigmoid', 'leaky_relu'])
        model.add(Dense(hp.Int(f'dense_units_{i+2}', 32, 512, step=32)))
        if activation_dense == "leaky_relu":
            model.add(LeakyReLU())
        else:
            model.add(Activation(activation_dense))
        model.add(Dropout(hp.Float(f'dropout_{i+2}', 0.0, 0.5, step=0.1)))

    # Output Layer
    model.add(Dense(y_train_cat.shape[1], activation='softmax'))

    # Compiling with a choice of learning rate
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=hp.Choice('learning_rate', learning_rates)),
                  loss='categorical_crossentropy', 
                  metrics=['accuracy'])

    return model
'''
import gc  # for garbage collection

def build_model(hp):

    input_shape = (1000, 12)

    model = Sequential()

    # Input Layer
    activation_1 = hp.Choice('activation_1', values=['relu', 'leaky_relu'])
    model.add(Conv1D(filters=hp.Int('filters_1', 16, 256, step=32), 
                     kernel_size=hp.Int('kernel_size_1', 2, 8, step=1),
                     input_shape=input_shape))
    if activation_1 == "leaky_relu":
        model.add(LeakyReLU())
    else:
        model.add(Activation(activation_1))
    model.add(MaxPooling1D(pool_size=2))

    # Additional Convolutional Layers
    for i in range(hp.Int('num_conv_layers', 1, 3)):
        activation_conv = hp.Choice(f'activation_conv_{i+2}', values=['relu', 'tanh', 'sigmoid', 'leaky_relu'])
        model.add(Conv1D(filters=hp.Int(f'filters_{i+2}', 16, 256, step=32), 
                         kernel_size=hp.Int(f'kernel_size_{i+2}', 2, 8, step=2)))
        if activation_conv == "leaky_relu":
            model.add(LeakyReLU())
        else:
            model.add(Activation(activation_conv))
        model.add(MaxPooling1D(pool_size=2))

    model.add(Flatten())

    # Dense Layers
    activation_dense_1 = hp.Choice('activation_dense_1', values=['relu', 'tanh', 'sigmoid', 'leaky_relu'])
    model.add(Dense(hp.Int('dense_units_1', 32, 512, step=32)))
    if activation_dense_1 == "leaky_relu":
        model.add(LeakyReLU())
    else:
        model.add(Activation(activation_dense_1))
    model.add(Dropout(hp.Float('dropout_1', 0.0, 0.5, step=0.1)))

    for i in range(hp.Int('num_dense_layers', 1, 2)):
        activation_dense = hp.Choice(f'activation_dense_{i+2}', values=['relu', 'tanh', 'sigmoid', 'leaky_relu'])
        model.add(Dense(hp.Int(f'dense_units_{i+2}', 32, 512, step=32)))
        if activation_dense == "leaky_relu":
            model.add(LeakyReLU())
        else:
            model.add(Activation(activation_dense))
        model.add(Dropout(hp.Float(f'dropout_{i+2}', 0.0, 0.5, step=0.1)))

    # Output Layer
    model.add(Dense(y_train_cat.shape[1], activation='softmax'))

    # Compiling with a choice of learning rate
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=hp.Choice('learning_rate', learning_rates)),
                  loss='categorical_crossentropy', 
                  metrics=['accuracy'])

    return model

# Custom callback for memory management
class MemoryCleanerCallback(Callback):
    def on_epoch_end(self, epoch, logs=None):
        gc.collect()
    def on_train_end(self, logs=None):
        gc.collect()


# 3. Set up RandomSearch with KerasTuner
tuner = RandomSearch(
    build_model,
    objective='val_loss',
    max_trials=64,
    executions_per_trial=1,
    directory='random_search_logs',
    project_name='kerastuner_wandb_integration')

# Add the MemoryCleanerCallback to the list of callbacks
tuner.search(X_train, y_train_cat, 
             epochs=100,
             batch_size=32,
             validation_split=0.2, 
             callbacks=[WandbCallback(save_model=False), early_stopping])
# Out:
# C:\Users\milal\IdeaProjects\Projektarbeit_KI_EKG\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 147
#     143         gc.collect()
#     146 # 3. Set up RandomSearch with KerasTuner
# --> 147 tuner = RandomSearch(
#     148     build_model,
#     149     objective='val_loss',
#     150     max_trials=64,
#     151     executions_per_trial=1,
#     152     directory='random_search_logs',
#     153     project_name='kerastuner_wandb_integration')
#     155 # Add the MemoryCleanerCallback to the list of callbacks
#     156 tuner.search(X_train, y_train_cat,
#     157              epochs=100,
#     158              batch_size=32,
#     159              validation_split=0.2,
#     160              callbacks=[WandbCallback(save_model=False), early_stopping])
#
# File ~\IdeaProjects\Projektarbeit_KI_EKG\.venv\Lib\site-packages\keras_tuner\src\tuners\randomsearch.py:174, in RandomSearch.__init__(self, hypermodel, objective, max_trials, seed, hyperparameters, tune_new_entries, allow_new_entries, max_retries_per_trial, max_consecutive_failed_trials, **kwargs)
#     163 self.seed = seed
#     164 oracle = RandomSearchOracle(
#     165     objective=objective,
#     166     max_trials=max_trials,
#    (...)    172     max_consecutive_failed_trials=max_consecutive_failed_trials,
#     173 )
# --> 174 super().__init__(oracle, hypermodel, **kwargs)
#
# File ~\IdeaProjects\Projektarbeit_KI_EKG\.venv\Lib\site-packages\keras_tuner\src\engine\tuner.py:122, in Tuner.__init__(self, oracle, hypermodel, max_model_size, optimizer, loss, metrics, distribution_strategy, directory, project_name, logger, tuner_id, overwrite, executions_per_trial, **kwargs)
#     114 if hypermodel is None and self.__class__.run_trial is Tuner.run_trial:
#     115     raise ValueError(
#     116         "Received `hypermodel=None`. We only allow not specifying "
#     117         "`hypermodel` if the user defines the search space in "
#     118         "`Tuner.run_trial()` by subclassing a `Tuner` class without "
#     119         "using a `HyperModel` instance."
#     120     )
# --> 122 super().__init__(
#     123     oracle=oracle,
#     124     hypermodel=hypermodel,
#     125     directory=directory,
#     126     project_name=project_name,
#     127     logger=logger,
#     128     overwrite=overwrite,
#     129     **kwargs,
#     130 )
#     132 self.max_model_size = max_model_size
#     133 self.optimizer = optimizer
#
# File ~\IdeaProjects\Projektarbeit_KI_EKG\.venv\Lib\site-packages\keras_tuner\src\engine\base_tuner.py:132, in BaseTuner.__init__(self, oracle, hypermodel, directory, project_name, overwrite, **kwargs)
#     129     self.reload()
#     130 else:
#     131     # Only populate initial space if not reloading.
# --> 132     self._populate_initial_space()
#     134 # Run in distributed mode.
#     135 if dist_utils.has_chief_oracle() and not dist_utils.is_chief_oracle():
#     136     # Proxies requests to the chief oracle.
#     137     # Avoid import at the top, to avoid inconsistent protobuf versions.
#
# File ~\IdeaProjects\Projektarbeit_KI_EKG\.venv\Lib\site-packages\keras_tuner\src\engine\base_tuner.py:192, in BaseTuner._populate_initial_space(self)
#     190 self.hypermodel.declare_hyperparameters(hp)
#     191 self.oracle.update_space(hp)
# --> 192 self._activate_all_conditions()
#
# File ~\IdeaProjects\Projektarbeit_KI_EKG\.venv\Lib\site-packages\keras_tuner\src\engine\base_tuner.py:149, in BaseTuner._activate_all_conditions(self)
#     147 hp = self.oracle.get_space()
#     148 while True:
# --> 149     self.hypermodel.build(hp)
#     150     self.oracle.update_space(hp)
#     152     # Update the recorded scopes.
#
# Cell In[23], line 129, in build_model(hp)
#     126     model.add(Dropout(hp.Float(f'dropout_{i+2}', 0.0, 0.5, step=0.1)))
#     128 # Output Layer
# --> 129 model.add(Dense(y_train_cat.shape[1], activation='softmax'))
#     131 # Compiling with a choice of learning rate
#     132 model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=hp.Choice('learning_rate', learning_rates)),
#     133               loss='categorical_crossentropy',
#     134               metrics=['accuracy'])
#
# NameError: name 'y_train_cat' is not defined

# %%
# 5. Retrain best model to get the history
best_model = tuner.get_best_models(num_models=1)[0]
history = best_model.fit(X_train, y_train_cat, epochs=10, validation_split=0.2).history

plt.figure(figsize=(10, 6))
plt.plot(history['accuracy'], label='Accuracy')
plt.plot(history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Save plot to a file
plot_filename = "accuracy_plot.png"
plt.savefig(plot_filename)
plt.show()

# 6. Log test metrics and plot to wandb
test_loss, test_accuracy = best_model.evaluate(X_test, y_test_cat)
wandb.log({'test_loss': test_loss, 'test_accuracy': test_accuracy, 'Accuracy Plot': wandb.Image(plot_filename)})

# 7. Save the best model and display its parameters
best_model.save("best_model.h5")
print("Best Model Parameters:", tuner.oracle.get_best_trials(num_trials=1)[0].hyperparameters.values)
wandb.finish()
# Out:
# Epoch 1/10
# 366/366 [==============================] - 8s 14ms/step - loss: 0.5055 - accuracy: 0.8255 - val_loss: 0.6513 - val_accuracy: 0.7726
# Epoch 2/10
# 366/366 [==============================] - 5s 12ms/step - loss: 0.4843 - accuracy: 0.8325 - val_loss: 0.6554 - val_accuracy: 0.7688
# Epoch 3/10
# 366/366 [==============================] - 5s 13ms/step - loss: 0.4664 - accuracy: 0.8375 - val_loss: 0.6692 - val_accuracy: 0.7609
# Epoch 4/10
# 366/366 [==============================] - 5s 12ms/step - loss: 0.4385 - accuracy: 0.8505 - val_loss: 0.7046 - val_accuracy: 0.7664
# Epoch 5/10
# 366/366 [==============================] - 5s 12ms/step - loss: 0.4255 - accuracy: 0.8535 - val_loss: 0.7186 - val_accuracy: 0.7599
# Epoch 6/10
# 366/366 [==============================] - 5s 12ms/step - loss: 0.3999 - accuracy: 0.8600 - val_loss: 0.6991 - val_accuracy: 0.7609
# Epoch 7/10
# 366/366 [==============================] - 5s 12ms/step - loss: 0.3826 - accuracy: 0.8658 - val_loss: 0.6999 - val_accuracy: 0.7603
# Epoch 8/10
# 366/366 [==============================] - 5s 12ms/step - loss: 0.3473 - accuracy: 0.8840 - val_loss: 0.7280 - val_accuracy: 0.7521
# Epoch 9/10
# 366/366 [==============================] - 5s 12ms/step - loss: 0.3182 - accuracy: 0.8949 - val_loss: 0.7469 - val_accuracy: 0.7606
# Epoch 10/10
# 366/366 [==============================] - 5s 12ms/step - loss: 0.2989 - accuracy: 0.8983 - val_loss: 0.7871 - val_accuracy: 0.7456
# 52/52 [==============================] - 0s 7ms/step - loss: 0.8193 - accuracy: 0.7536
# Best Model Parameters: {'activation_1': 'leaky_relu', 'filters_1': 208, 'kernel_size_1': 5, 'num_conv_layers': 3, 'activation_conv_2': 'leaky_relu', 'filters_2': 240, 'kernel_size_2': 2, 'activation_dense_1': 'tanh', 'dense_units_1': 384, 'dropout_1': 0.0, 'num_dense_layers': 2, 'activation_dense_2': 'leaky_relu', 'dense_units_2': 128, 'dropout_2': 0.4, 'learning_rate': 0.0001, 'activation_conv_3': 'leaky_relu', 'filters_3': 176, 'kernel_size_3': 6, 'activation_conv_4': 'leaky_relu', 'filters_4': 16, 'kernel_size_4': 6, 'activation_dense_3': 'sigmoid', 'dense_units_3': 256, 'dropout_3': 0.0}
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▂▄▂█▃▃▅██▂▂▃▅▅▂▂▅▂▇▁▂▃▂▂▂▁▁▄▇▅▇▂▅▂▄█▂▁▃▂</td></tr><tr><td>epoch</td><td>▁▄▂▃▂▃█▂▂▁▃▂▆▁▁▁▃▃▃▂▁▂▃▁▂▄▃▃▃▂▁▂▂▂▁▃▂▁▁▂</td></tr><tr><td>loss</td><td>▆▄▆▁▅▅▄▁▁▆▆▅▃▄▅█▃▇▁▇▆▅▆▆▆▇▇▄▁▃▂▆▃▆▄▁▆▇▅▆</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▃▆▁▅▄▅▇▆▆▁▁▄▇▆▄▁█▁█▁▅▄▁▁▁▁▁▅▆▇▄▁▆▁▇▇▁▁▅▁</td></tr><tr><td>val_loss</td><td>▃▂▄▅▂▂▁█▆▄▄▂▂▂▃█▁▄▃▅▂▂▄▄▄▅▄▂▆▁▄▄▂▄▁▆▄▄▂▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.5749</td></tr><tr><td>best_epoch</td><td>27</td></tr><tr><td>best_val_loss</td><td>1.31084</td></tr><tr><td>epoch</td><td>47</td></tr><tr><td>loss</td><td>1.24317</td></tr><tr><td>test_accuracy</td><td>0.75363</td></tr><tr><td>test_loss</td><td>0.81931</td></tr><tr><td>val_accuracy</td><td>0.49453</td></tr><tr><td>val_loss</td><td>1.36379</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">dauntless-jazz-34</strong> at: <a href='https://wandb.ai/gtu/EKG-CONV1D/runs/ohstm5hl' target="_blank">https://wandb.ai/gtu/EKG-CONV1D/runs/ohstm5hl</a><br/>Synced 6 W&B file(s), 65 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20
#   adding: wandb/latest-run/tmp/code/ (stored 0%)
#   adding: wandb/debug-internal.log (deflated 96%)

# %%
from IPython.display import FileLink
FileLink(r'wandb.zip')
# Out:
# /kaggle/working/wandb.zip

# %%
'''
import os
import shutil

# Ana dizindeki tüm dosya ve klasörleri listele
for root, dirs, files in os.walk(".", topdown=False):
    for name in files:
        try:
            os.remove(os.path.join(root, name))
        except:
            pass
    for name in dirs:
        try:
            shutil.rmtree(os.path.join(root, name))
        except:
            pass
'''
# Out:
# '\nimport os\nimport shutil\n\n# Ana dizindeki tüm dosya ve klasörleri listele\nfor root, dirs, files in os.walk(".", topdown=False):\n    for name in files:\n        try:\n            os.remove(os.path.join(root, name))\n        except:\n            pass\n    for name in dirs:\n        try:\n            shutil.rmtree(os.path.join(root, name))\n        except:\n            pass\n'

# %%
from tensorflow.keras.layers import MultiHeadAttention

def build_model(hp):
    model = Sequential()

    # Input Layer
    activation_1 = hp.Choice('activation_1', values=['relu', 'tanh', 'sigmoid', 'leaky_relu'])
    model.add(Conv1D(filters=hp.Int('filters_1', 16, 256, step=32), 
                     kernel_size=hp.Int('kernel_size_1', 2, 8, step=1),
                     input_shape=input_shape))
    if activation_1 == "leaky_relu":
        model.add(LeakyReLU())
    else:
        model.add(Activation(activation_1))
    model.add(MaxPooling1D(pool_size=2))

    # Additional Convolutional Layers
    for i in range(hp.Int('num_conv_layers', 1, 3)):
        activation_conv = hp.Choice(f'activation_conv_{i+2}', values=['relu', 'tanh', 'sigmoid', 'leaky_relu'])
        model.add(Conv1D(filters=hp.Int(f'filters_{i+2}', 16, 256, step=32), 
                         kernel_size=hp.Int(f'kernel_size_{i+2}', 2, 8, step=2)))
        if activation_conv == "leaky_relu":
            model.add(LeakyReLU())
        else:
            model.add(Activation(activation_conv))
        model.add(MaxPooling1D(pool_size=2))

    # Add Multi-Head Attention Mechanism
    model.add(MultiHeadAttention(num_heads=hp.Int('num_heads', 2, 8, step=2), key_dim=hp.Int('key_dim', 32, 128, step=32)))
    model.add(Flatten())

    # Dense Layers
    activation_dense_1 = hp.Choice('activation_dense_1', values=['relu', 'tanh', 'sigmoid', 'leaky_relu'])
    model.add(Dense(hp.Int('dense_units_1', 32, 512, step=32)))
    if activation_dense_1 == "leaky_relu":
        model.add(LeakyReLU())
    else:
        model.add(Activation(activation_dense_1))
    model.add(Dropout(hp.Float('dropout_1', 0.0, 0.5, step=0.1)))

    for i in range(hp.Int('num_dense_layers', 1, 2)):
        activation_dense = hp.Choice(f'activation_dense_{i+2}', values=['relu', 'tanh', 'sigmoid', 'leaky_relu'])
        model.add(Dense(hp.Int(f'dense_units_{i+2}', 32, 512, step=32)))
        if activation_dense == "leaky_relu":
            model.add(LeakyReLU())
        else:
            model.add(Activation(activation_dense))
        model.add(Dropout(hp.Float(f'dropout_{i+2}', 0.0, 0.5, step=0.1)))

    # Output Layer
    model.add(Dense(y_train_cat.shape[1], activation='softmax'))

    # Compiling with a choice of learning rate
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=hp.Choice('learning_rate', learning_rates)),
                  loss='categorical_crossentropy', 
                  metrics=['accuracy'])

    return model
